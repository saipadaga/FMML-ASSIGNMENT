# %% [markdown]
# <a href="https://colab.research.google.com/github/saipadaga/FMML-ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 11:42:53--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   168MB/s    in 0.4s
#
# 2024-03-30 11:42:55 (168 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3341 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 2469   1612.02161v2  A key limitation of sampling algorithms for ap...    cs
# 22870  1709.06970v1  Bayesian graphical models are a useful tool fo...  stat
# 27465  1703.07939v2  In this paper we are interested in the problem...    cs
# 21971   1112.3699v8  In this article, we have proposed several appr...  stat
# 22549  1611.04208v3  It has been proposed that complex populations,...  stat
# ...             ...                                                ...   ...
# 14691   1005.3902v1  This paper describes in details the first vers...    cs
# 13384   1108.4080v1  We present a number of bounds on convergence t...    cs
# 17935  cs/9610101v1  This paper lays part of the groundwork for a d...    cs
# 7134   1710.07438v1  A common practice in most of deep convolutiona...    cs
# 25743  1511.04659v1  In remote sensing, images acquired by various ...    cs
#
#                                                    title  year  \
# 2469   Measuring the non-asymptotic convergence of se...  2016
# 22870  An Expectation Conditional Maximization approa...  2017
# 27465  Recurrent Multimodal Interaction for Referring...  2017
# 21971               Ensemble Models with Trees and Rules  2011
# 22549  Joint mean and covariance estimation with unre...  2016
# ...                                                  ...   ...
# 14691     Morphonette: a morphological network of French  2010
# 13384  Convergence Properties of Two (μ + λ) Evolutio...  2011
# 17935  Mechanisms for Automated Negotiation in State ...  1996
# 7134   Unified Backpropagation for Multi-Objective De...  2017
# 25743  Implementation and comparative quantitative as...  2015
#
#                                                 keywords
# 2469   [limitation, algorithms, approximate, inferenc...
# 22870  [graphical, understanding, dependence, relatio...
# 27465  [interested, segmentation, descriptions, refer...
# 21971  [approaches, processing, prediction, simulatio...
# 22549  [populations, dependencies, observations, vari...
# ...                                                  ...
# 14691  [describes, morphonette, morphological, radica...
# 13384  [convergence, population, evolutionary, algori...
# 17935  [groundwork, negotiation, classifying, interac...
# 7134   [convolutional, architectures, connected, acti...
# 25743  [observation, satellites, resolution, pansharp...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 2469     [limitation, algorithms, approximate, inferenc...
# 22870    [graphical, understanding, dependence, relatio...
# 27465    [interested, segmentation, descriptions, refer...
# 21971    [approaches, processing, prediction, simulatio...
# 22549    [populations, dependencies, observations, vari...
#                                ...
# 22298    [recursive, partitioning, approaches, producin...
# 39160    [parameterized, parameter, determines, paramet...
# 6893     [challenge, tomography, maintaining, reconstru...
# 37691    [experiment, automated, mathematical, discover...
# 2563     [databases, healthcare, routinely, aggregated,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8943 words.
# Out of those 4544 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f5269164-9c74-4ceb-a335-c59b48478005" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5269164-9c74-4ceb-a335-c59b48478005")) {                    Plotly.newPlot(                        "f5269164-9c74-4ceb-a335-c59b48478005",                        [{"x":["approximate","symmetric","asymptotic","assumptions","distributions","measuring","programming","dirichlet","metropolis","experiments","particles","divergence","algorithms","approximation","distribution","resampling","limitation","difficult","convergence","sequential","posterior","probabilistic","technique","multinomial","importance","regression","inference","conditional","infeasible","dimensional","understanding","rendering","extending","expectation","computationally","variables","exploration","incorporate","relationships","graphical","selection","deterministic","stochastic","alternative","maximization","particularly","situations","estimation","information","algorithm","dependence","segmentation","representations","combining","effective","multimodal","intermediate","interested","interactions","independently","descriptions","referring","recurrent","sentences","interaction","empirically","benchmark","expressions","convolutional","outperforms","individual","modalities","approaches","performance","prediction","developed","processing","simulations","considered","quantitative","promising","techniques","challenge","populations","analyzing","challenging","efficiently","inferences","differential","observations","generalized","estimating","conventional","parameters","advantages","penalized","covariance","utilizing","calibrated","structures","statistics","consistency","expression","simulation","statistical","dependencies","accounting","estimated","practical","structure","illustrate","establish","correctly","outperform","denoising","dependency","algorithmic","synthetic","effectively","important","simultaneously","competitive","including","answering","orthogonal","forgetting","irrelevant","remembering","mechanism","transformed","homogeneous","consequence","constructed","prewhitening","invariant","treatment","functions","multiplicative","direction","construct","identifying","categories","successfully","annotated","generation","computational","annotations","additionally","perspective","attractive","necessary","available","recognition","agreement","classifier","multilayer","processes","generalizations","approximated","supervised","uncertainty","estimates","decoupled","parameterized","layerwise","calculating","covariances","hierarchical","flexibility","predictive","architecture","intervals","improvement","optimization","demonstrate","adjustments","discovery","confidence","conducted","maximizing","parameter","uncertainties","methodologies","component","wasserstein","complexity","reduction","corresponding","functional","consisting","representing","compositional","disambiguation","considers","semantics","transitive","plausibility","transform","constructing","investigation"],"y":[117,22,14,62,103,38,133,20,5,601,6,21,613,109,200,8,22,144,121,61,41,153,264,8,84,105,222,84,9,185,157,20,23,37,91,117,56,60,63,50,165,34,128,115,31,80,49,214,687,862,18,192,233,110,253,37,36,19,66,40,34,7,113,62,79,87,216,42,379,245,147,40,423,862,234,207,306,51,125,78,112,396,160,13,55,266,168,16,37,78,72,68,103,231,94,8,18,41,7,148,57,49,51,70,136,54,6,73,125,327,75,47,26,103,47,37,47,121,120,345,127,125,269,46,22,6,14,1,107,23,19,21,65,1,70,39,208,9,64,97,78,71,92,54,136,286,55,64,61,18,74,250,358,21,159,19,112,11,14,164,84,68,4,12,1,16,3,111,26,48,242,24,131,336,553,2,54,34,79,32,118,15,22,113,4,220,108,145,49,50,75,34,14,40,117,6,8,71,43,40],"type":"bar"},{"x":["approximate","symmetric","asymptotic","assump ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4544,), (4544, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8141666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style='background-color:rgba(0, 255, 0, 0.5652173913043479);'>Detection</span> <span style=''>of</span> <span style=''>Faint</span> <span style=''>Edges</span> <span style=''>in</span> <span style=''>Noisy</span> <span style=''>Images</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>question</span> <span style=''>for</span> <span style=''>edge</span> <span style='background-color:rgba(0, 255, 0, 0.5652173913043479);'>detection</span> <span style=''>in</span> <span style=''>noisy</span> <span style=''>images</span> <span style=''>is</span> <span style=''>how</span> <span style=''>faint</span> <span style=''>can</span> <span style=''>an</span> <span style=''>edge</span> <span style=''>be</span> <span style=''>and</span> <span style=''>still</span> <span style=''>be</span> <span style=''>detected</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>offer</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.388888888888889);'>formalism</span> <span style=''>to</span> <span style=''>study</span> <span style=''>this</span> <span style=''>question</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923077);'>subsequently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiscale</span> <span style=''>edge</span> <span style='background-color:rgba(0, 255, 0, 0.5652173913043479);'>detection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>faint</span> <span style=''>edges</span> <span style=''>in</span> <span style=''>noisy</span> <span style=''>images</span> <span style=''>In</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.388888888888889);'>formalism</span> <span style=''>we</span> <span style=''>view</span> <span style=''>edge</span> <span style='background-color:rgba(0, 255, 0, 0.5652173913043479);'>detection</span> <span style=''>as</span> <span style=''>a</span> <span style=''>search</span> <span style=''>in</span> <span style=''>a</span> <span style=''>discrete</span> <span style=''>though</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potentially</span> <span style=''>large</span> <span style=''>set</span> <span style=''>of</span> <span style=''>feasible</span> <span style=''>curves</span> <span style=''>First</span> <span style=''>we</span> <span style=''>derive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.377049180327869);'>expressions</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5652173913043479);'>detection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>threshold</span> <span style=''>as</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style=''>curve</span> <span style=''>length</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>search</span> <span style=''>space</span> <span style=''>We</span> <span style=''>then</span> <span style=''>present</span> <span style=''>two</span> <span style=''>edge</span> <span style='background-color:rgba(0, 255, 0, 0.5652173913043479);'>detection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>one</span> <span style=''>for</span> <span style=''>straight</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Perspective</span> <span style=''>on</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Filtering</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Smoothing</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>on</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothing</span> <span style=''>This</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>show</span> <span style=''>that</span> <span style=''>common</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>Gaussian</span> <span style=''>filteringsmoothing</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distinguished</span> <span style=''>solely</span> <span style=''>by</span> <span style=''>their</span> <span style=''>methods</span> <span style=''>of</span> <span style=''>computingapproximating</span> <span style=''>the</span> <span style=''>means</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariances</span> <span style=''>of</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>This</span> <span style=''>implies</span> <span style=''>that</span> <span style=''>novel</span> <span style=''>filters</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothers</span> <span style=''>can</span> <span style=''>be</span> <span style=''>derived</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>straightforwardly</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>these</span> <span style=''>moments</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>this</span> <span style=''>insight</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>the</span> <span style=''>cubature</span> <span style=''>Kalman</span> <span style=''>smoother</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Gibbs</span> <span style=''>sampling</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style=''>Learning</span> <span style=''>of</span> <span style=''>k</span> <span style=''>CNF</span> <span style=''>Boolean</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Functions</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>revisits</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>k</span> <span style=''>CNF</span> <span style=''>Boolean</span> <span style=''>function</span> <span style=''>from</span> <span style=''>examples</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>online</span> <span style=''>learning</span> <span style=''>under</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.34883720930232553);'>logarithmic</span> <span style=''>loss</span> <span style=''>In</span> <span style=''>doing</span> <span style=''>so</span> <span style=''>we</span> <span style=''>give</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>to</span> <span style=''>one</span> <span style=''>of</span> <span style=''>Valiants</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>celebrated</span> <span style=''>PAC</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>which</span> <span style=''>we</span> <span style=''>then</span> <span style=''>build</span> <span style=''>upon</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicting</span> <span style=''>the</span> <span style=''>output</span> <span style=''>of</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>k</span> <span style=''>CNF</span> <span style=''>Boolean</span> <span style=''>function</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>loss</span> <span style=''>of</span> <span style=''>our</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cumulative</span> <span style=''>log</span> <span style=''>loss</span> <span style=''>can</span> <span style=''>be</span> <span style=''>upper</span> <span style=''>bounded</span> <span style=''>ignoring</span> <span style='background-color:rgba(255, 0, 0, 0.34883720930232553);'>logarithmic</span> <span style=''>factors</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>each</span> <span style=''>example</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Greedy</span> <span style=''>Subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>given</span> <span style=''>points</span> <span style=''>that</span> <span style=''>lie</span> <span style=''>on</span> <span style=''>or</span> <span style=''>near</span> <span style=''>the</span> <span style=''>union</span> <span style=''>of</span> <span style=''>many</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>recover</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>To</span> <span style=''>this</span> <span style=''>end</span> <span style=''>one</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifies</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>points</span> <span style=''>close</span> <span style=''>to</span> <span style=''>the</span> <span style=''>same</span> <span style=''>subspace</span> <span style=''>and</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>sets</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subspaces</span> <span style=''>As</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>clusters</span> <span style=''>(linear</span> <span style=''>subspaces)</span> <span style=''>forbids</span> <span style=''>proper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>general</span> <span style=''>distance</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>such</span> <span style=''>as</span> <span style=''>K</span> <span style=''>means</span> <span style=''>many</span> <span style=''>model</span> <span style=''>specific</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>new</span> <span style=''>simple</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>analysis</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guaranteed</span> <span style=''>exact</span> <span style=''>(perfect)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>under</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>on</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>points</span> <span style=''>and</span> <span style=''>the</span> <span style=''>affinity</span> < ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10983488872936109)
# 	evaluation (0.10050251256281408)
# 	architecture (0.08686288585786073)
# 	experimental (0.14178033022254127)
# 	representation (0.14034458004307251)
# 	information (0.24659009332376167)
# 	detection (0.12921751615218952)
# 	different (0.27351040918880115)
# 	recognition (0.12849964106245512)
# 	convolutional (0.13603732950466618)
#
# Some Statistics words are:
# 	stochastic (0.1400198609731877)
# 	algorithm (0.4051638530287984)
# 	estimation (0.17477656405163852)
# 	variables (0.14299900695134063)
# 	distribution (0.17328699106256207)
# 	statistical (0.15342601787487586)
# 	dimensional (0.17477656405163852)
# 	theoretical (0.1608738828202582)
# 	inference (0.19761668321747766)
# 	regression (0.17676266137040714)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bce72e33-800b-4e08-99b4-a56c7049b23e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bce72e33-800b-4e08-99b4-a56c7049b23e")) {                    Plotly.newPlot(                        "bce72e33-800b-4e08-99b4-a56c7049b23e",                        [{"x":["approximate","symmetric","asymptotic","assumptions","distributions","measuring","programming","dirichlet","metropolis","experiments","particles","divergence","algorithms","approximation","distribution","resampling","limitation","difficult","convergence","sequential","posterior","probabilistic","technique","multinomial","importance","regression","inference","conditional","infeasible","dimensional","understanding","rendering","extending","expectation","computationally","variables","exploration","incorporate","relationships","graphical","selection","deterministic","stochastic","alternative","maximization","particularly","situations","estimation","information","algorithm","dependence","segmentation","representations","combining","effective","multimodal","intermediate","interested","interactions","independently","descriptions","referring","recurrent","sentences","interaction","empirically","benchmark","expressions","convolutional","outperforms","individual","modalities","approaches","performance","prediction","developed","processing","simulations","considered","quantitative","promising","techniques","challenge","populations","analyzing","challenging","efficiently","inferences","differential","observations","generalized","estimating","conventional","parameters","advantages","penalized","covariance","utilizing","calibrated","structures","statistics","consistency","expression","simulation","statistical","dependencies","accounting","estimated","practical","structure","illustrate","establish","correctly","outperform","denoising","dependency","algorithmic","synthetic","effectively","important","simultaneously","competitive","including","answering","orthogonal","forgetting","irrelevant","remembering","mechanism","transformed","homogeneous","consequence","constructed","prewhitening","invariant","treatment","functions","multiplicative","direction","construct","identifying","categories","successfully","annotated","generation","computational","annotations","additionally","perspective","attractive","necessary","available","recognition","agreement","classifier","multilayer","processes","generalizations","approximated","supervised","uncertainty","estimates","decoupled","parameterized","layerwise","calculating","covariances","hierarchical","flexibility","predictive","architecture","intervals","improvement","optimization","demonstrate","adjustments","discovery","confidence","conducted","maximizing","parameter","uncertainties","methodologies","component","wasserstein","complexity","reduction","corresponding","functional","consisting","representing","compositional","disambiguation","considers","semantics","transitive","plausibility","transform","constructing","investigation","distributional","behaviorally","probability","variations","characterization","explanatory","computable","extremely","recognizing","intrinsic","exploring","automatic","coherence","embedding","assigning","regarding","relationship","representation","addressed","boundaries","framework","experimental","formulate","different","evaluating","especially","effectiveness","underlying","knowledge","furthermore","meaningful","impossible","classifiers","predicting","restricted","kernelized","description","unstructured","criterion","represent","implementation","additional","constitutes","quantifies","therefore","completed","structural","equivalence","computing","intervention","closeness","properties","statements","significantly","ef ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	generalisations
# 	tightness
# 	unanswered
# 	multisensor
# 	determinants
# 	penalizations
# 	majorization
# 	noiseless
# 	electrocardiograms
# 	symmetrization
# 	connectome
# 	unidentifiability
# 	bernsteins
# 	integrable
# 	econometrics
# 	discarding
# 	pioneering
# 	certificate
# 	workhorse
# 	extrapolate
# Some words which never appear in Statistics papers:
# 	disambiguation
# 	plausibility
# 	irregularities
# 	abstracted
# 	consecutively
# 	deduction
# 	offspring
# 	recombination
# 	benefiting
# 	treebanks
# 	syntactic
# 	skeletons
# 	kinematic
# 	observers
# 	affective
# 	blackwell
# 	approachability
# 	blackwells
# 	authorities
# 	organisational

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.086038760646834e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7658333333333334
